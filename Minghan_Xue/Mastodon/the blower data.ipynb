# %%
import requests
from mastodon import Mastodon, MastodonNotFoundError, MastodonRatelimitError, StreamListener
import csv, os, time, json

# %%
def delete_mastodon_status(status_id, access_token):
    url = "https://mastodon.social/@jionghao/api/v1/statuses/{}".format(status_id)
    headers = {
        "Authorization": "Bearer {}".format(access_token),
    }

    response = requests.delete(url, headers=headers)

    if response.status_code == 200:
        print("Status deleted successfully!")
        print(response.json())
    elif response.status_code == 404:
        print("Status not found. It may have been already deleted or the status ID is incorrect.")
    else:
        print("Error deleting status. HTTP status code: {}".format(response.status_code))
        print(response.text)

# %%
def stream_federated_timeline_given_hashtag(access_token, hashtag):
    URL = "https://theblower.au/api/v1/timelines/tag/{}".format(hashtag)
    headers = {
        "Authorization": "Bearer {}".format(access_token),
    }

    response = requests.get(URL, headers=headers)

    if response.status_code == 200:
        #print("Get the local timeline successfully!")
        data_list = response.json()
        return data_list
    else:
        if response.status_code == 404:
            print("Failed to get local timeline")
        else:
            print("Error get local timeline. HTTP status code: {}".format(response.status_code))
            print(response.text)
        return []  # return an empty list on failure

# %%
def full_text_search(access_token):
    URL = "https://theblower.au/api/v2/search?q={}".format(keyword)
    headers = {
        "Authorization": "Bearer {}".format(access_token),
    }
    
    response = requests.get(URL, headers=headers)

    if response.status_code == 200:
        #print("Get the request text successfully!")
        print(response.json())
    elif response.status_code == 404:
        print("Failed to get the request text")
    else:
        print("Error get the request text. HTTP status code: {}".format(response.status_code))
        print(response.text)

# %%
def streaming_Mastodon_timeline():
    pass
if __name__ == "__main__":
    access_token = "Z3wfKjDDfUxzL5Zp9XTCbe0OKBm3EuMI1Y6BeDuEHOM"  
    status_id = "110197044539110917"
    keywords = ["homeless", "tramp", "vagrant"]

    output_file = "theblower_homeless_data.json"
    results = []
    for keyword in keywords:
        data = stream_federated_timeline_given_hashtag(access_token, keyword)
        results.extend(data)
        print(data)

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=4)
# Out:
# [{'id': '110347624531815443', 'created_at': '2023-05-11T02:12:05.000Z', 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://mastodon.social/users/laprice/statuses/110347624462382041', 'url': 'https://mastodon.social/@laprice/110347624462382041', 'replies_count': 0, 'reblogs_count': 2, 'favourites_count': 0, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'content': '<p><a href="https://mastodon.social/tags/Oregon" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Oregon</span></a> city and county officials taking a helicopter ride to look at <a href="https://mastodon.social/tags/homeless" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>homeless</span></a> issues is just perfect.<br>An expensive technocratic solution that barely pretends to do anything about the issue.<br><a href="https://www.bendbulletin.com/localstate/debone-kebler-take-to-the-skies-for-perspective-on-homelessness/article_5c069ba6-edfb-11ed-bdab-8ff06fcaa298.html" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">bendbulletin.com/localstate/de</span><span class="invisible">bone-kebler-take-to-the-skies-for-perspective-on-homelessness/article_5c069ba6-edfb-11ed-bdab-8ff06fcaa298.html</span></a></p>', 'filtered': [], 'reblog': None, 'account': {'id': '109346330036513249', 'username': 'laprice', 'acct': 'laprice@mastodon.social', 'display_name': 'tooting for a better world', 'locked': False, 'bot': False, 'discoverable': True, 'group': False, 'created_at': '2017-01-03T00:00:00.000Z', 'note': '<p>Pronouns he/him<br>Incipient post-economist.<br>Self-domesticated philosopher.<br>Support Strike for climate. <br>Support the fundamental right of bodily  autonomy.</p>', 'url': 'https://mastodon.social/@laprice', 'avatar': 'https://static.theblower.au/cache/accounts/avatars/109/346/330/036/513/249/original/84318bd075c182be.jpg', 'avatar_static': 'https://static.theblower.au/cache/accounts/avatars/109/346/330/036/513/249/original/84318bd075c182be.jpg', 'header': 'https://static.theblower.au/cache/accounts/headers/109/346/330/036/513/249/original/482185c32da0a0a4.jpg', 'header_static': 'https://static.theblower.au/cache/accounts/headers/109/346/330/036/513/249/original/482185c32da0a0a4.jpg', 'followers_count': 327, 'following_count': 927, 'statuses_count': 2329, 'last_status_at': '2023-05-11', 'emojis': [], 'fields': []}, 'media_attachments': [], 'mentions': [], 'tags': [{'name': 'oregon', 'url': 'https://theblower.au/tags/oregon'}, {'name': 'homeless', 'url': 'https://theblower.au/tags/homeless'}], 'emojis': [], 'card': {'url': 'https://www.bendbulletin.com/localstate/debone-kebler-take-to-the-skies-for-perspective-on-homelessness/article_5c069ba6-edfb-11ed-bdab-8ff06fcaa298.html', 'title': 'DeBone, Kebler take to the skies for perspective on homelessness', 'description': 'Tension between the elected city and county officials came to a head in March after an agreement to create a managed homeless camp on the south side of Bend dissipated.', 'type': 'link', 'author_name': '', 'author_url': '', 'provider_name': 'The Bulletin', 'provider_url': '', 'html': '', 'width': 400, 'height': 211, 'image': 'https://static.theblower.au/cache/preview_cards/images/001/883/668/original/76bb7f3b2c15679d.jpg', 'embed_url': '', 'blurhash': 'UsI=0}OYs:WA_NWYj[bHpJsCS2oft7ofR*n$'}, 'poll': None}, {'id': '110341335099811284', 'created_at': '2023-05-09T23:32:35.000Z', 'in_reply_to_id': '110341306197556100', 'in_reply_to_account_id': '109593860134535219', 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://universeodon.com/users/AnneTheWriter1/statuses/110341334994399073', 'url': 'https://universeodon.com/@AnneTheWriter1/110341334994399073', 'replies_count': 0, 'reblogs_c ...
# []
# []

# %%
if __name__ == "__main__":
    access_token = "Z3wfKjDDfUxzL5Zp9XTCbe0OKBm3EuMI1Y6BeDuEHOM"  
    status_id = "110197044539110917"
    keywords = ["mortgage", "pledge", "hypothec", "guaranty", "pawn"]

    output_file = "theblower_mortgage_data.json"
    results = []
    for keyword in keywords:
        data = stream_federated_timeline_given_hashtag(access_token, keyword)
        results.extend(data)
        print(data)

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=4)
# Out:
# [{'id': '110308858247879743', 'created_at': '2023-05-04T05:53:17.000Z', 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://zirk.us/users/ChrisMayLA6/statuses/110308858080726324', 'url': 'https://zirk.us/@ChrisMayLA6/110308858080726324', 'replies_count': 2, 'reblogs_count': 5, 'favourites_count': 0, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'content': '<p>More good news if you have a <a href="https://zirk.us/tags/mortgage" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>mortgage</span></a> whose costs are spiralling... you\'ll be relieved to know that after I posted the happy news that both Barclays &amp; NatWest profits were up... so are Lloyds!</p><p>I know you\'ll be relieved that the extra money you\'re paying is keeping the banks in a healthy state &amp; their shareholders in line for healthy dividends.</p><p>As you wonder whether you can feed your children, or pay for you <a href="https://zirk.us/tags/energy" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>energy</span></a>, just feel warm inside that you\'re helping someone else.</p><p>[irony klaxon]</p>', 'filtered': [], 'reblog': None, 'account': {'id': '109364646131295768', 'username': 'ChrisMayLA6', 'acct': 'ChrisMayLA6@zirk.us', 'display_name': 'Emeritus Prof Christopher May', 'locked': False, 'bot': False, 'discoverable': True, 'group': False, 'created_at': '2022-11-18T00:00:00.000Z', 'note': '<p>Retired Professor of Political Economy<br>(Lancaster University, UK - retired 2021)<br>(also <a href="https://zirk.us/tags/ProfDJ" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>ProfDJ</span></a> across the Lune Valley)<br>Contributor: North West Bylines</p>', 'url': 'https://zirk.us/@ChrisMayLA6', 'avatar': 'https://static.theblower.au/cache/accounts/avatars/109/364/646/131/295/768/original/645113986a0dc1bb.jpeg', 'avatar_static': 'https://static.theblower.au/cache/accounts/avatars/109/364/646/131/295/768/original/645113986a0dc1bb.jpeg', 'header': 'https://static.theblower.au/cache/accounts/headers/109/364/646/131/295/768/original/96b49ec3b8fae834.jpeg', 'header_static': 'https://static.theblower.au/cache/accounts/headers/109/364/646/131/295/768/original/96b49ec3b8fae834.jpeg', 'followers_count': 1984, 'following_count': 100, 'statuses_count': 5476, 'last_status_at': '2023-05-10', 'emojis': [], 'fields': [{'name': 'DJ repertoire(s)', 'value': "Jazz nights; Soul/funk nights; Disco classics night; 70's night", 'verified_at': None}, {'name': 'Academic interests', 'value': 'Critical Political Economy; Art History; Music business', 'verified_at': None}, {'name': 'Reading', 'value': "Art History; Science Fiction; 'Literary' fiction; classics", 'verified_at': None}, {'name': 'Past Lives', 'value': 'Music industry (studio/retail); Bookseller (family business); political pressure group', 'verified_at': None}]}, 'media_attachments': [], 'mentions': [], 'tags': [{'name': 'mortgage', 'url': 'https://theblower.au/tags/mortgage'}, {'name': 'energy', 'url': 'https://theblower.au/tags/energy'}], 'emojis': [], 'card': None, 'poll': None}, {'id': '110285639582759753', 'created_at': '2023-04-30T03:28:30.000Z', 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://aus.social/users/mojo/statuses/110285639536215018', 'url': 'https://aus.social/@mojo/110285639536215018', 'replies_count': 0, 'reblogs_count': 1, 'favourites_count': 0, 'edited_at': '2023-04-30T03:46:38.000Z', 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'content': '<p>The <a href="https://aus.social/tags/mortgage" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>mortgage</span></a> trap -  During the pandemic, a ...
# [{'id': '110316875504911716', 'created_at': '2023-05-05T15:52:10.000Z', 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://mastodon.online/users/Susan_Larson_TN/statuses/110316875313865337', 'url': 'https://mastodon.online/@Susan_Larson_TN/110316875313865337', 'replies_count': 0, 'reblogs_count': 0, 'favourites_count': 0, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'content': '<p><a href="https://mastodon.online/tags/Florida" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Florida</span></a> <a href="https://mastodon.online/tags/mayors" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>mayors</span></a> <a href="https://mastodon.online/tags/pledge" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>pledge</span></a> <a href="https://mastodon.online/tags/support" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>support</span></a> for <a href="https://mastodon.online/tags/LGBTQ" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>LGBTQ</span></a> <a href="https://mastodon.online/tags/community" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>community</span></a> amid passage of <a href="https://mastodon.online/tags/Fascist" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Fascist</span></a> <a href="https://mastodon.online/tags/bills" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>bills</span></a>. </p><p><a href="https://mastodon.online/tags/Mayors" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Mayors</span></a> from <a href="https://mastodon.online/tags/Orlando" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Orlando</span></a>, <a href="https://mastodon.online/tags/Tampa" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Tampa</span></a> and more signed the <a href="https://mastodon.online/tags/pledge" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>pledge</span></a>, according to <a href="https://mastodon.online/tags/glsen" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>glsen</span></a> </p><p><a href="https://mastodon.online/tags/Women" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Women</span></a> <a href="https://mastodon.online/tags/Transgender" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Transgender</span></a> <a href="https://mastodon.online/tags/LGBTQIA" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>LGBTQIA</span></a> <a href="https://mastodon.online/tags/Florida" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Florida</span></a> <a href="https://mastodon.online/tags/RepublicanParty" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>RepublicanParty</span></a> <a href="https://mastodon.online/tags/Fascism" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Fascism</span></a> <a href="https://mastodon.online/tags/Hate" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Hate</span></a> <a href="https://mastodon.online/tags/Bigotry" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Bigotry</span></a> <a href="https://mastodon.online/tags/Violence" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Violence</span></a> <a href="https://mastodon.online/tags/Genocide" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Geno ...
# []
# []
# []

# %%
if __name__ == "__main__":
    access_token = "Z3wfKjDDfUxzL5Zp9XTCbe0OKBm3EuMI1Y6BeDuEHOM"  
    status_id = "110197044539110917"
    keywords = ["rent", "chummage", "rental"]

    output_file = "theblower_rent_data.json"
    results = []
    for keyword in keywords:
        data = stream_federated_timeline_given_hashtag(access_token, keyword)
        results.extend(data)
        print(data)

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=4)
# Out:
# [{'id': '110341417984821268', 'created_at': '2023-05-09T23:53:40.000Z', 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://mastodon.social/users/PBruce/statuses/110341417892342348', 'url': 'https://mastodon.social/@PBruce/110341417892342348', 'replies_count': 0, 'reblogs_count': 1, 'favourites_count': 0, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'content': '<p><a href="https://mastodon.social/tags/Cdnpoli" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Cdnpoli</span></a> <a href="https://mastodon.social/tags/Nspoli" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Nspoli</span></a> <a href="https://mastodon.social/tags/Rent" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Rent</span></a> <a href="https://mastodon.social/tags/Halifax" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Halifax</span></a> <a href="https://mastodon.social/tags/Housing" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Housing</span></a> <a href="https://mastodon.social/tags/Stigma" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Stigma</span></a> <a href="https://mastodon.social/tags/Poverty" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Poverty</span></a> </p><p>On Tuesday, regional council moved ahead with the plan to create a new framework that would require all new developments to either include affordable units or put up cash-in-lieu to build units elsewhere.</p><p>Long, long, past due &amp; has important social benefits for all , while reducing the stigma.of poverty , a very important benefit.</p><p>Building codes kept/keep the poor out and create both poverty &amp;  homelessness </p><p><a href="https://www.cbc.ca/news/canada/nova-scotia/halifax-council-rejects-developer-s-request-to-back-out-of-building-affordable-housing-1.6837775" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">cbc.ca/news/canada/nova-scotia</span><span class="invisible">/halifax-council-rejects-developer-s-request-to-back-out-of-building-affordable-housing-1.6837775</span></a></p>', 'filtered': [], 'reblog': None, 'account': {'id': '109368282962846037', 'username': 'PBruce', 'acct': 'PBruce@mastodon.social', 'display_name': 'Pat', 'locked': False, 'bot': False, 'discoverable': True, 'group': False, 'created_at': '2022-11-07T00:00:00.000Z', 'note': '<p>Canadian .Newfoundlander  In NS . Politics, current events ,science law, Justice , Equality and Equity  <a href="https://mastodon.social/tags/Disability" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Disability</span></a> , <a href="https://mastodon.social/tags/MentalHealth" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>MentalHealth</span></a>  , Retired. Support Public Healthcare, UBI ,Live &amp; let live . Climate change is real. What you ignore you empower.It is in the shelter of each other that we live. I wear a mask  Occupation  (retired)  Problem Solver, Fixing what others break ,People &amp; Organizations</p>', 'url': 'https://mastodon.social/@PBruce', 'avatar': 'https://static.theblower.au/cache/accounts/avatars/109/368/282/962/846/037/original/947bd0e3fcf5c86e.jpg', 'avatar_static': 'https://static.theblower.au/cache/accounts/avatars/109/368/282/962/846/037/original/947bd0e3fcf5c86e.jpg', 'header': 'https://static.theblower.au/cache/accounts/headers/109/368/282/962/846/037/original/f5b9f47c46cd9bd9.jpg', 'header_static': 'https://static.theblower.au/cache/accounts/headers/109/368/282/962/846/037/original/f5b9f47c46cd9bd9.jpg', 'followers_count': 784, 'following_count': 933, 'statuses_count': ...
# []
# [{'id': '110344095118089861', 'created_at': '2023-05-10T11:14:30.000Z', 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://aus.social/users/RichForrest2/statuses/110344095057043860', 'url': 'https://aus.social/@RichForrest2/110344095057043860', 'replies_count': 0, 'reblogs_count': 2, 'favourites_count': 0, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'content': '<p><a href="https://aus.social/tags/nsw" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>nsw</span></a> <a href="https://aus.social/tags/outlaws" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>outlaws</span></a> <a href="https://aus.social/tags/secret" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>secret</span></a> <a href="https://aus.social/tags/Rental" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Rental</span></a> <a href="https://aus.social/tags/bidding" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>bidding</span></a> <a href="https://aus.social/tags/auspol" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>auspol</span></a> </p><p><a href="https://www.9news.com.au/national/nsw-rental-reforms-outlaw-rent-bidding-portable-bond-scheme-bill-introduced-parliament/a4ab6d92-7267-420b-abfe-2caa0fc9babf" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">9news.com.au/national/nsw-rent</span><span class="invisible">al-reforms-outlaw-rent-bidding-portable-bond-scheme-bill-introduced-parliament/a4ab6d92-7267-420b-abfe-2caa0fc9babf</span></a></p>', 'filtered': [], 'reblog': None, 'account': {'id': '109346944422375710', 'username': 'RichForrest2', 'acct': 'RichForrest2@aus.social', 'display_name': 'Richard Forrester - 🐦 escapee', 'locked': False, 'bot': False, 'discoverable': False, 'group': False, 'created_at': '2022-11-05T00:00:00.000Z', 'note': "<p>Commenting &amp; working towards social justice &amp; a better future for people and animals alike<br>Having a laugh at myself along the way<br>Doesn't play well with trolls<br>Living on Bunurong/Boon Wurrung lands.</p>", 'url': 'https://aus.social/@RichForrest2', 'avatar': 'https://static.theblower.au/cache/accounts/avatars/109/346/944/422/375/710/original/0cd260d438bc905d.jpg', 'avatar_static': 'https://static.theblower.au/cache/accounts/avatars/109/346/944/422/375/710/original/0cd260d438bc905d.jpg', 'header': 'https://static.theblower.au/cache/accounts/headers/109/346/944/422/375/710/original/9b8b4068a7a8a7d0.jpg', 'header_static': 'https://static.theblower.au/cache/accounts/headers/109/346/944/422/375/710/original/9b8b4068a7a8a7d0.jpg', 'followers_count': 131, 'following_count': 127, 'statuses_count': 2812, 'last_status_at': '2023-05-11', 'emojis': [], 'fields': []}, 'media_attachments': [], 'mentions': [], 'tags': [{'name': 'nsw', 'url': 'https://theblower.au/tags/nsw'}, {'name': 'outlaws', 'url': 'https://theblower.au/tags/outlaws'}, {'name': 'secret', 'url': 'https://theblower.au/tags/secret'}, {'name': 'rental', 'url': 'https://theblower.au/tags/rental'}, {'name': 'bidding', 'url': 'https://theblower.au/tags/bidding'}, {'name': 'auspol', 'url': 'https://theblower.au/tags/auspol'}], 'emojis': [], 'card': {'url': 'https://www.9news.com.au/national/nsw-rental-reforms-outlaw-rent-bidding-portable-bond-scheme-bill-introduced-parliament/a4ab6d92-7267-420b-abfe-2caa0fc9babf', 'title': 'NSW moves to eliminate secret bidding in rental overhaul', 'description': "<p>The NSW government is moving to have s\ufeffecret rent bidding outlawed under an overhaul to the state's tenancy laws.</p>", 'type': 'link', 'author_name': 'Daniel Jeffrey', 'author_url': '', 'provider_name': '9News', 'provider_url': '', 'html': '', ...

# %%
if __name__ == "__main__":
    access_token = "Z3wfKjDDfUxzL5Zp9XTCbe0OKBm3EuMI1Y6BeDuEHOM"  
    status_id = "110197044539110917"
    keywords = ["income", "earning"]

    output_file = "theblower_income_data.json"
    results = []
    for keyword in keywords:
        data = stream_federated_timeline_given_hashtag(access_token, keyword)
        results.extend(data)
        print(data)

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=4)
# Out:
# [{'id': '110304886969427168', 'created_at': '2023-05-03T13:03:19.000Z', 'in_reply_to_id': '110304805625917821', 'in_reply_to_account_id': '109524002123624710', 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://econtwitter.net/users/RichStein/statuses/110304886752520537', 'url': 'https://econtwitter.net/@RichStein/110304886752520537', 'replies_count': 0, 'reblogs_count': 0, 'favourites_count': 0, 'edited_at': '2023-05-03T13:04:17.000Z', 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'content': '<p>Website: Gabriel Zucman (includes links to complete papers, other publications, contributions to policy debates) <a href="https://gabriel-zucman.eu/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">gabriel-zucman.eu/</span><span class="invisible"></span></a><br><a href="https://econtwitter.net/tags/WealthInequality" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WealthInequality</span></a> <a href="https://econtwitter.net/tags/IncomeInequality" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>IncomeInequality</span></a> <a href="https://econtwitter.net/tags/Inequality" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Inequality</span></a> <a href="https://econtwitter.net/tags/TaxAvoidance" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>TaxAvoidance</span></a> <a href="https://econtwitter.net/tags/TaxEvasion" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>TaxEvasion</span></a> <a href="https://econtwitter.net/tags/WealthTax" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WealthTax</span></a> <a href="https://econtwitter.net/tags/IncomeTax" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>IncomeTax</span></a> <a href="https://econtwitter.net/tags/IncomeDistribution" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>IncomeDistribution</span></a> <a href="https://econtwitter.net/tags/wealth" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>wealth</span></a> <a href="https://econtwitter.net/tags/income" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>income</span></a> <a href="https://econtwitter.net/tags/data" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>data</span></a></p>', 'filtered': [], 'reblog': None, 'account': {'id': '109524002123624710', 'username': 'RichStein', 'acct': 'RichStein@econtwitter.net', 'display_name': 'Rich Stein (he/him)', 'locked': False, 'bot': False, 'discoverable': False, 'group': False, 'created_at': '2022-11-09T00:00:00.000Z', 'note': '<p>Economist for non-profits, NGOs, governments, some private cos. Projects—public <a href="https://econtwitter.net/tags/policy" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>policy</span></a>, <a href="https://econtwitter.net/tags/evaluation" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>evaluation</span></a>, <a href="https://econtwitter.net/tags/innovation" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>innovation</span></a>, <a href="https://econtwitter.net/tags/tech" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>tech</span></a>, job creation, <a href="https://econtwitter.net/tags/privacy" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>privacy</span></a>, <a href="https://econtwitter.net/tags/health" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>health</span></a>, <a href="https://econtwitter.net/tags/equity" class="mention hashtag" rel="nofollow noopener noreferr ...
# []
